# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [1,2,3,4,5]
x1 = [10,20,30,40]
x2 = ["a","s","d","f"]
y2 = [10,20,30,40]

# %%
# Merging two plots
plt.plot(x,y,color="r")
#plt.pie([1],colors="r")
plt.pie(x)
plt.bar(x2,y2)
plt.show()

# %%
# ek plot mey 4 graphs saath mey chahiye to subplot use karo and subplot ke andar position specify karo

plt.subplot(2,2,1) #(no_of_rows,no_of_columns,no_of_index)
plt.plot(x,y,color="r")

plt.subplot(2,2,2)
plt.pie([1],colors="r")

x1 = [10,20,30,40]
plt.subplot(2,2,3)
plt.pie(x)

x2 = ["a","s","d","f"]
y2 = [10,20,30,40]
plt.subplot(2,2,4)
plt.bar(x2,y2)

plt.show()
