# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [1,2,3,4,5]
x1 = [10,20,30,40,50]

# %%
plt.plot(x,y,color="r")
plt.show()

# %%
plt.plot(x,y,color="r")
plt.pie([1],colors="r")
plt.pie(x)
plt.show()
