# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [1,2,3,4,5]

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,color="r")
plt.title("Python")
plt.xlabel("X - Axis")
plt.ylabel("Y - Axis")
plt.show()

# %%
plt.fill_between(x,y)
plt.title("Python")
plt.xlabel("X - Axis")
plt.ylabel("Y - Axis")
plt.show()

# %%
# agar aap chahte ho ke line ke bich mey box banaya jaaye to enter values in x and y
plt.plot(x,y)
plt.fill_between(x=[2,4],y1=2,y2=4)
plt.title("Python")
plt.xlabel("X - Axis")
plt.ylabel("Y - Axis")
plt.show()

# %%
plt.plot(x,y,color="r")
plt.fill_between(x=[2,4],y1=2,y2=4)
plt.title("Python")
plt.xlabel("X - Axis")
plt.ylabel("Y - Axis")
plt.show()

# %%
# If you want to change the color of the box to use color parameter in fill_between
plt.plot(x,y,color="black")
plt.fill_between(x=[2,4],y1=2,y2=4,color="m")
plt.title("Python")
plt.xlabel("X - Axis")
plt.ylabel("Y - Axis")
plt.show()
