# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
x = np.random.randint(10,60,(50)) #10 se le kar 60 ke bich mey 50 values chahiye
print(x)
# Out:
# [17 17 23 58 43 12 20 11 38 34 54 32 55 30 43 17 21 33 55 20 20 29 28 33
#  49 39 23 50 34 45 58 14 36 14 46 10 18 20 14 52 24 46 57 43 42 12 21 14
#  16 38]

# %%
num = [17,17,23,58,43,12,20,11,38,34 ,54, 32, 55, 30, 43, 17, 21, 33, 55, 20, 20, 29, 28, 33,
 49, 39, 23, 50, 34, 45, 58, 14, 36, 14, 46, 10, 18, 20, 14, 52, 24, 46, 57, 43, 42, 12, 21, 14,
 16, 38]
plt.hist(num)
plt.show()

# %%
plt.xlabel("Python")
plt.ylabel("Number")
plt.title("Yash")
plt.hist(num)
plt.show()
